# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelachmann/social-media-lab/blob/main/notebooks/2024_11_18_BERTopic_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BERTopic [![DOI](https://zenodo.org/badge/660157642.svg)](https://zenodo.org/badge/latestdoi/660157642)
# ![Notes on (Computational) Social Media Research Banner](https://raw.githubusercontent.com/michaelachmann/social-media-lab/main/images/banner.png)
#
# ## Overview
#
# This Jupyter notebook is a part of the social-media-lab.net project, which is a work-in-progress textbook on computational social media analysis. The notebook is intended for use in my classes.
#
# The **BERTopic** Notebook uses the `bertopic` package for transformer based topic modeling. The package has an excellent documentation: https://maartengr.github.io/BERTopic/index.html and a tutorial notebook: https://github.com/MaartenGr/BERTopic/blob/master/notebooks/BERTopic.ipynb
#
# **2024 Updates:**
# * Updated the sample data to the US 2024 Elections
# * Replaced German with English stopword list
# * Added a cell top combine Topics with Documents
#
# ### Project Information
#
# - Project Website: [social-media-lab.net](https://social-media-lab.net/)
# - GitHub Repository: [https://github.com/michaelachmann/social-media-lab](https://github.com/michaelachmann/social-media-lab)
#
# ## License Information
#
# This notebook, along with all other notebooks in the project, is licensed under the following terms:
#
# - License: [GNU General Public License version 3.0 (GPL-3.0)](https://www.gnu.org/licenses/gpl-3.0.de.html)
# - License File: [LICENSE.md](https://github.com/michaelachmann/social-media-lab/blob/main/LICENSE.md)
#
#
# ## Citation
#
# If you use or reference this notebook in your work, please cite it appropriately. Here is an example of the citation:
#
# ```
# Michael Achmann. (2024). michaelachmann/social-media-lab: 2024-11-18 (v0.0.14). Zenodo. https://doi.org/10.5281/zenodo.8199901
# ```

# %% [markdown]
# ## Import the Data Frame
# ### CrowdTangle

# %%
#@markdown Read the `csv` file. Select the correct `text_column` below. We called this column `Text` in our **Text Master** table (see [Preprocessing Notebook](https://github.com/michaelachmann/social-media-lab/blob/main/notebooks/2024_11_11_Preprocessing.ipynb) and [OCR & Whisper Documentation](https://social-media-lab.net/processing/preprocessing.html#ocr-whisper)). When using raw data from i.e. **4CAT / Zeeschuimer** the Instagram caption column is called `body`, in **Meta Content Library Exports** it is `text`.

import pandas as pd

csv_file = "/content/drive/MyDrive/2024-11-18-US-Sample.csv" #@param {type:"string"}
text_column = "text" #@param {type:"string"}


df = pd.read_csv(csv_file)

# %% [markdown]
# *Note:* The data used in this tutorial has been retrieved through the Meta Content Library [1]. Snippets shown are for demonstration purposes only, while the datasets are part of my ongoing research.
#
# [1] Meta Platforms, Inc. (n.d.). Meta Content Library API version v5.0. https://doi.org/10.48680/meta.metacontentlibraryapi.5.0

# %% [markdown]
# ## BERTopic

# %%
# !pip install -q bertopic
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 65.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.5 MB/s eta 0:00:00

# %% [markdown]
# In the following cells we download a stopword dictionary for the German language and applied it according to [the documentation](https://maartengr.github.io/BERTopic/faq.html#how-do-i-remove-stop-words)

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

# Replace with "german" for German social media texts.
STOPWORDS = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words=STOPWORDS)

# %% [markdown]
# Now we're ready to create our corpus in `docs`, a list of text documents to pass to `BERTopic`.

# %%
# We create our corpus

# We filter empty captions out
filtered_df = df[~pd.isna(df[text_column])]

# And create a list of documents
docs = filtered_df[text_column].tolist()

# %% [markdown]
# For this tutorial I chose the *simplest* version of BERTopic. [The Documentation](https://maartengr.github.io/BERTopic/index.html#installation) offers **a lot** of ideas to improve your topic models.

# %%
from bertopic import BERTopic

# When dealing with German texts choose 'multilingual'.
# When dealing with English texts exclusively, choose 'english'
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2024-11-18 09:44:49,940 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/351 [00:00<?, ?it/s]
# 2024-11-18 09:45:09,624 - BERTopic - Embedding - Completed ✓
# 2024-11-18 09:45:09,625 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-11-18 09:45:18,238 - BERTopic - Dimensionality - Completed ✓
# 2024-11-18 09:45:18,241 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-11-18 09:46:00,385 - BERTopic - Cluster - Completed ✓
# 2024-11-18 09:46:00,393 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-11-18 09:46:02,473 - BERTopic - Representation - Completed ✓

# %% [markdown]
# **The following cells have been copied from the [BERTopic Tutorial](https://github.com/MaartenGr/BERTopic/blob/master/notebooks/BERTopic.ipynb).** Please check the linked notebook for more functions and the documentation for more background information.

# %% [markdown]
# ## Extracting Topics
# After fitting our model, we can start by looking at the results. Typically, we look at the most frequent topics first as they best represent the collection of documents.

# %%
freq = topic_model.get_topic_info(); freq.head(5)
# Out:
#    Topic  Count                                               Name  \
# 0     -1   3503                -1_trump_kamalaharris_election_vote
# 1      0    183  0_redactedmention_redactedmention redactedment...
# 2      1    135  1_redactedmention_redactedmention redactedment...
# 3      2    132                2_garden_rally_square_square garden
# 4      3    130            3_vote_voting_trump kamala_kamalaharris
#
#                                       Representation  \
# 0  [trump, kamalaharris, election, vote, kamala, ...
# 1  [redactedmention, redactedmention redactedment...
# 2  [redactedmention, redactedmention redactedment...
# 3  [garden, rally, square, square garden, madison...
# 4  [vote, voting, trump kamala, kamalaharris, vot...
#
#                                  Representative_Docs
# 0  [GARBAGE GATE: The White House press office al...
# 1  [Follow <redacted_mention>.\n.\n.\n.\n.\n.\n.\...
# 2  [What’s The Reason Men Don’t Know How To Act A...
# 3  [Media across the spectrum framed headlines ar...
# 4  [Happy voting day America! Your 2 main candida...

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
len(freq)
# Out:
# 247

# %% [markdown]
# We have a total of 52 topics

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('redactedmention', 0.034268711110545434),
#  ('redactedmention redactedmention', 0.03101189735711171),
#  ('redactedmention trump', 0.015278780092564016),
#  ('trump redactedmention', 0.011812356869575508),
#  ('trump2024', 0.008812790024905162),
#  ('repost', 0.007661381022314542),
#  ('maga', 0.007292623754943119),
#  ('repost redactedmention', 0.0069858916403627794),
#  ('follow', 0.0069641741565703765),
#  ('trump', 0.006952301504586322)]

# %% [markdown]
# ## Combine Topics with Documents

# %%
# Create a DataFrame from topics and probs with the filtered indices

post_ids = filtered_df['id'].tolist()

docs_w_topics_df = pd.DataFrame({
    'post_id': post_ids,
    'caption': docs,
    'topic': topics,
})

# %%
docs_w_topics_df.head()
# Out:
#             post_id                                            caption  topic
# 0  1246922449869249  🚨Did I hear that right!? \n\n𝔀𝔀𝔀.𝓢𝓮𝓪𝓞𝓯𝓜𝓾𝓭.𝓬𝓸𝓶\...      0
# 1   380723045031443  New ‘Kamalexa’ Amazon Echo Rambles And Never A...      6
# 2  1511705799536753  🩸🇺🇸🦅 BLOOD OF JESUS CLEAN THE STREETS OF OUR N...      5
# 3   488940517503443  #Trump #Republicans #MAGA #TrumpSupporters #GO...      4
# 4  3908844146026596  Make America $CHILL Again 🫡\n\n#LumiChill #Tru...     21

# %% [markdown]
# ## Visualize Topics
# After having trained our `BERTopic` model, we can iteratively go through perhaps a hundred topic to get a good
# understanding of the topics that were extract. However, that takes quite some time and lacks a global representation.
# Instead, we can visualize the topics that were generated in a way very similar to
# [LDAvis](https://github.com/cpsievert/LDAvis):

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ed3c89e7-3a4b-42fb-b69a-770edd4a6e4b" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed3c89e7-3a4b-42fb-b69a-770edd4a6e4b")) {                    Plotly.newPlot(                        "ed3c89e7-3a4b-42fb-b69a-770edd4a6e4b",                        [{"customdata":[[0,"redactedmention | redactedmention redactedmention | redactedmention trump | trump redactedmention | trump2024",183],[1,"redactedmention | redactedmention redactedmention | kamalaharris | kamala | trump kamala",135],[2,"garden | rally | square | square garden | madison square",132],[3,"vote | voting | trump kamala | kamalaharris | voted",130],[4,"maga | trump maga | maga trump | america | trump2024",127],[5,"jesus | christian | christ | christians | bible",113],[6,"kamalaharris | harris kamalaharris | harris | kamala | harris donaldtrump",109],[7,"rogan | joe rogan | joe | podcast | joerogan",109],[8,"trump trump | trump | habba | jexit | whales",108],[9,"vote | right | voting | voice | make",106],[10,"mcdonalds | fries | trump mcdonalds | mcdonalds trump | drivethru",96],[11,"bitcoin | crypto | btc | cryptocurrency | trading",91],[12,"israel | palestinians | gaza | israeli | netanyahu",89],[13,"elections2024 | trump harris | election2024 | harris | harris trump",80],[14,"halloween | happy halloween | costume | happy | halloween trump",76],[15,"trump kamala | kamala | kamala trump | win | skate",73],[16,"tax | income | economy | income tax | economic",69],[17,"poll | points | north carolina | polls | lead",69],[18,"harrisjayaraj | harrisjayaraj harris | tamilsong | yuvan | yuvanshankarraja",67],[19,"latest | latest redactedmention | battlegroundnewscom | battlegroundnewscom election2024 | swingstate headlines",66],[20,"puerto | puerto rico | rico | island | floating",62],[21,"trump2024 | trump2024 trump | trump trump2024 | make america | america great",61],[22,"international | newsdaily newsroom | trendingnews newsmedia | dailynews worldnews | news international",60],[23,"abortion | reproductive | rights | care | abortion rights",58],[24,"mpuncensored | mpuncensored misfitpatriot | uncancellable | themisfitpatriot uncancellable | themisfitpatriot",55],[25,"hitler | kelly | staff | chief staff | fascist",55],[26,"vibrant | tap sharetag | reelsinstagram trump | sharetag | vibranterprise viralreels",54],[27,"trump harris | harris supporters | harris | harris usa | uselection",54],[28,"american usa | foodie | faith racing | sprintcars | explorepage space",53],[29,"day | election day | vote | matter | get",52],[30,"palm beach | palm | confident | beach | fair",50],[31,"beyonce | dance | dance party | party beyonce | beyonc",49],[32,"personaldevelopement | selfhelp personaldevelopement | selfimprovement selfhelp | selfhelp | finance personalfinance",48],[33,"kamala harris | kamala | longislandlongislandnylinylongislandnewyorksuffolkcountynynassaucountynyelection2024donaldtrumptrumpkamalaharrisharrispresidentpresidentialelectionvotevoting | harris donald | harris",48],[34,"walz | tim walz | tim | governor | governor tim",46],[35,"go vote | vote | ur | willing get | trump harris",46],[36,"jesuschrist | kamalaharris jesuschrist | jesuschrist trump | jesuschrist kamalaharris | trump jesuschrist",45],[37,"jews | jewish | palestine | israel | hamas",45],[38,"podcast | jamalbryantpod | episode jamal | jamalbryantpodcast | season episode",45],[39,"womensrights votingrights | environment love | maga abortion | votingrights humanrights | humanrights environment",45],[40,"project2025 | vote voteblue | veteran | voteblue | votevets",45],[41,"garbage | biden | supporters garbage | biden joebiden | joebiden",43],[42,"trump kamalaharris | kamalaharris trump | kamalaharris | k ...

# %% [markdown]
# ## Visualize Terms
#
# We can visualize the selected terms for a few topics by creating bar charts out of the c-TF-IDF scores for each topic representation. Insights can be gained from the relative c-TF-IDF scores between and within topics. Moreover, you can easily compare topic representations to each other.

# %%
topic_model.visualize_barchart(top_n_topics=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57d86b60-3b98-45bb-a1a2-99ded5bd43a6" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57d86b60-3b98-45bb-a1a2-99ded5bd43a6")) {                    Plotly.newPlot(                        "57d86b60-3b98-45bb-a1a2-99ded5bd43a6",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008812790024905162,0.011812356869575508,0.015278780092564016,0.03101189735711171,0.034268711110545434],"y":["trump2024  ","trump redactedmention  ","redactedmention trump  ","redactedmention redactedmention  ","redactedmention  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008168159951058495,0.008475134344075442,0.010564417012880817,0.019854272028513153,0.024972219315775437],"y":["trump kamala  ","kamala  ","kamalaharris  ","redactedmention redactedmention  ","redactedmention  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019332690131126734,0.0193650181549744,0.01955430290430807,0.02032648469843435,0.020490311566804663],"y":["madison square  ","square garden  ","square  ","rally  ","garden  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.009261205229997646,0.009554668285120685,0.010476741415825292,0.011460346702811207,0.017421644221646188],"y":["voted  ","kamalaharris  ","trump kamala  ","voting  ","vote  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0115420570138242,0.012233099954828927,0.02005386351260687,0.023922294212101555,0.03949510812363747],"y":["trump2024  ","america  ","maga trump  ","trump maga  ","maga  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.014627928080237164,0.01802712486007203,0.01951727315464201,0.021791217719260132,0.03309399032901304],"y":["bible  ","christians  ","christ  ","christian  ","jesus  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013585816488631912,0.013816532430253329,0.014287988169279326,0.01808841694950342,0.019293044979939316],"y":["harris donaldtrump  ","kamala  ","harris  ","harris kamalaharris  ","kamalaharris  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01766017551737651,0.01831251018740102,0.023407840760357013,0.03093051431896441,0.05075715586158621],"y":["joerogan  ","podcast  ","joe  ","joe rogan  ","rogan  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.019484891193347346,0.02020318703157843,0.02334371401762754,0.028218064556744537,0.14176177159046696],"y":["whales  ","jexit  ","habba  ","trump  ","trump trump  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.006739249475723124,0.007009170836041135,0.007041834625566785,0.00729324546624934,0.010421244845078515],"y":["make  ","voice  ","voting  ","right  ","vote  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.010638355113682385,0.011588522342840945,0.01691723533079173,0.018254914709067618,0.06943316398620436],"y":["drivethru  ","mcdonalds trump  ","trump mcdonalds  ","fries  ","mcdonalds  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01428104069490132,0.019920436910347856,0.02167242422828139,0.05296766890454373,0.05419018362450265],"y":["trading  ","cryptocurrency  ","btc  ","crypto  ","bitcoin  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.013307665215355466,0.014662871814986343,0.017030454249866923,0.01845710 ...

# %% [markdown]
# ## Topic Reduction
# We can also reduce the number of topics after having trained a BERTopic model. The advantage of doing so,
# is that you can decide the number of topics after knowing how many are actually created. It is difficult to
# predict before training your model how many topics that are in your documents and how many will be extracted.
# Instead, we can decide afterwards how many topics seems realistic:

# %%
topic_model.reduce_topics(docs, nr_topics=15)
# Out:
# 2024-11-18 09:48:07,664 - BERTopic - Topic reduction - Reducing number of topics
# 2024-11-18 09:48:10,493 - BERTopic - Topic reduction - Reduced number of topics from 247 to 15

# %% [markdown]
# ## Visualize Terms Again

# %%
topic_model.visualize_barchart(top_n_topics=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d774c689-bd86-4492-abc2-e163b60b5d74" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d774c689-bd86-4492-abc2-e163b60b5d74")) {                    Plotly.newPlot(                        "d774c689-bd86-4492-abc2-e163b60b5d74",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013622023220696175,0.015521818409284398,0.016703875235065974,0.018860346588344998,0.02947276915011005],"y":["vote  ","redactedmention  ","election  ","harris  ","trump  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.026091260299108375,0.026091260299108375,0.026091260299108375,0.026091260299108375,0.038144169602334396],"y":["videoclip  ","indvssl  ","fitnesstransformation  ","olympics2024  ","fbvideo  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.07288629989652155,0.07309537171855546,0.09253118459159279,0.09253118459159279,0.09253118459159279],"y":["mercedes  ","mercedes clr  ","clr  ","gtr  ","clr gtr  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.052163536337995677,0.052163536337995677,0.05405493827330514,0.0560886514818389,0.0656968182263841],"y":["jumpoutboys  ","jumpoutboys fo  ","cops  ","copville  ","police  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.06232534546021407,0.06232534546021407,0.06709796250280409,0.07335153361625549,0.10703058325728984],"y":["bardigang  ","bardi  ","rally  ","redactedmention  ","cardi  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.06983027829745561,0.07102932425989193,0.08984839295881218,0.10421420081004988,0.11828648688748854],"y":["votes  ","electoralcollege  ","college  ","electoral college  ","electoral  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.10603507662270215,0.1130919836500325,0.11427734261329688,0.11991641625958126,0.17191232117578795],"y":["chase  ","approved  ","business funding  ","business  ","funding  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.05558742804816879,0.07358965834553333,0.11779780978955005,0.1220590821643286,0.12811312583143883],"y":["pennsylvania  ","took  ","northampton  ","northampton county  ","county  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03587061833293996,0.04809999478354699,0.04973521350478145,0.07405758879567183,0.07795313294587497],"y":["schedule appointment  ","houston  ","home  ","tx  ","8886718175  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.04065055884158398,0.06061038094451427,0.06397330242209587,0.07478328225469158,0.1433346243214922],"y":["stevebannon  ","steve bannon  ","steve  ","prison  ","bannon  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.06676064978495995,0.0673960259430075,0.07840295529093787,0.13935701040080192,0.17105399987526837],"y":["mt  ","tx dec  ","jan  ","dec  ","nov  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.5915457624728737,0.5968695213897786,0.6026197283420633,0.6026197283420633,0.6026197283420633],"y":["nationaldebt  ","paid national  ","pt nationaldebt  ","debt pt  ","nationaldebt trump  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.10422796630515616,0.1144024226074341,0.1144024226074341,0.14487450440139416,0.18749412549982802],"y":["dibuono bobintenseredactedmention  ","bobintense ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9e3283b5-b149-42b5-977b-783ec411a81f" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e3283b5-b149-42b5-977b-783ec411a81f")) {                    Plotly.newPlot(                        "9e3283b5-b149-42b5-977b-783ec411a81f",                        [{"customdata":[[0,"trump | harris | election | redactedmention | vote",7219],[1,"fbvideo | olympics2024 | fitnesstransformation | indvssl | videoclip",208],[2,"clr gtr | gtr | clr | mercedes clr | mercedes",53],[3,"police | copville | cops | jumpoutboys fo | jumpoutboys",41],[4,"cardi | redactedmention | rally | bardi | bardigang",35],[5,"electoral | electoral college | college | electoralcollege | votes",27],[6,"funding | business | business funding | approved | chase",19],[7,"county | northampton county | northampton | took | pennsylvania",18],[8,"8886718175 | tx | home | houston | schedule appointment",17],[9,"bannon | prison | steve | steve bannon | stevebannon",15],[10,"nov | dec | jan | tx dec | mt",13],[11,"nationaldebt trump | debt pt | pt nationaldebt | paid national | nationaldebt",12],[12,"redactedmention redactedmention | redactedmention | longisland | bobintenseredactedmention | dibuono bobintenseredactedmention",11],[13,"trade | entrepreneur daytrading | trader | daytrading | forex",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[7219,208,53,41,35,27,19,18,17,15,13,12,11,11],"sizemode":"area","sizeref":4.511875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[14.344975,13.498875,-6.187556,13.949557,15.986045,14.063905,-5.964266,12.875681,-5.67838,13.864288,14.496987,15.366958,14.571742,13.479132],"xaxis":"x","y":[7.0512624,7.124598,-10.604022,7.489849,5.219527,4.324962,-10.827569,6.9090114,-11.113253,6.5594206,6.762875,3.9438095,5.578223,5.737737],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5 ...

# %% [markdown]
# # **Model serialization**
# The model and its internal settings can easily be saved. Note that the documents and embeddings will not be saved. However, UMAP and HDBSCAN will be saved.

# %%
# Save model
topic_model.save("/content/drive/MyDrive/2024-11-18-US24-ContentLibrary-Posts-model")
# Out:
# 2024-11-18 09:39:37,698 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.
